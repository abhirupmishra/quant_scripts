# %% [markdown]
# ## Importing Libraries

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import plotly.express as px

import quandl
import yfinance as yf

from alphalens.utils import get_clean_factor_and_forward_returns
from alphalens.performance import factor_information_coefficient, mean_return_by_quantile, \
    factor_returns, factor_rank_autocorrelation, mean_information_coefficient

# %%
t_bill_yield = quandl.get(
    "USTREASURY/YIELD",
    authtoken="QNPX4RGB15s3fi5em9_Q",
    start_date='2010-01-01',
    end_date='2021-12-31'
)

# need to divide by 100 to get absolute values
t_bill_yield = t_bill_yield/100
t_bill_yield = t_bill_yield['1 MO']
t_bill_yield.name = '1M'

# %%
t_bill_yield
# Out:
# Date
# 2010-01-04    0.0005
# 2010-01-05    0.0003
# 2010-01-06    0.0003
# 2010-01-07    0.0002
# 2010-01-08    0.0002
#                ...
# 2021-12-27    0.0004
# 2021-12-28    0.0003
# 2021-12-29    0.0001
# 2021-12-30    0.0006
# 2021-12-31    0.0006
# Name: 1M, Length: 3004, dtype: float64

# %%
# loading the mid-cap screen
screen = pd.read_csv('../data/mid_cap_screen.csv')
screen = screen[['ticker', 'market_cap', '5D', 'Price', 'Sector']]
screen
# Out:
#    ticker    market_cap        5D   Price                  Sector
# 0     WPP  1.953425e+10 -0.023880   79.71       Consumer Cyclical
# 1    ULTA  1.891067e+10 -0.066919  349.42       Consumer Cyclical
# 2   FWONA  1.842348e+10 -0.038130   55.75       Consumer Cyclical
# 3    AMCR  1.832137e+10 -0.033953   11.95          Unknown Sector
# 4     WDC  1.801492e+10 -0.132503   57.81              Technology
# 5     BIP  1.785579e+10  0.014605   60.44               Utilities
# 6     PKX  1.761126e+10 -0.073132   57.92         Basic Materials
# 7     CVE  1.726562e+10 -0.053872   14.05                  Energy
# 8    GNRC  1.710748e+10 -0.114666  271.16             Industrials
# 9    VICI  1.709475e+10 -0.047652   27.18             Real Estate
# 10    PBA  1.705920e+10 -0.037244   31.02                  Energy
# 11   CTRA  1.572646e+10 -0.129279   19.33                  Energy
# 12    SJR  1.487249e+10 -0.011932   29.81  Communication Services
# 13    IEP  1.442620e+10 -0.052516   51.78             Industrials
# 14  LBTYA  1.436568e+10 -0.065018   26.46  Communication Services
# 15    UAL  1.348654e+10 -0.108900   41.65             Industrials
# 16  DISCA  1.324863e+10 -0.160038   26.19       Consumer Cyclical
# 17    IRM  1.255197e+10 -0.031718   43.35             Industrials
# 18   LUMN  1.231745e+10 -0.025122   12.03  Communication Services
# 19   MASI  1.203336e+10 -0.065085  217.91              Healthcare
# 20  EMRAF  1.193036e+10 -0.012076   47.45                 Unknown
# 21    KEP  1.124721e+10 -0.024499    8.76               Utilities
# 22   QGEN  1.110061e+10  0.004332   48.69              Healthcare
# 23   LAMR  1.086705e+10 -0.047391  107.34             Real Estate
# 24    MMP  1.014078e+10 -0.042716   47.51                  Energy
# 25    NWL  9.784200e+09 -0.035639   23.00      Consumer Defensive
# 26  C-P-N  9.741881e+09 -0.005852   27.18                 Unknown
# 27   PSXP  9.588003e+09 -0.053853   41.99                  Energy
# 28    WES  9.450151e+09 -0.037438   23.14                  Energy
# 29    BEP  8.869019e+09 -0.014656   32.27               Utilities
# 30    CLF  8.491539e+09 -0.229932   16.98         Basic Materials
# 31    AQN  8.393489e+09  0.013006   14.02               Utilities
# 32    GME  8.120669e+09 -0.088213  106.36       Consumer Cyclical
# 33    PNW  7.975163e+09 -0.021862   70.69               Utilities
# 34    DXC  7.703373e+09 -0.101500   30.54              Technology
# 35    OGE  7.468512e+09 -0.018158   37.31               Utilities
# 36   PLNT  7.262051e+09 -0.033764   83.85       Consumer Cyclical
# 37    PAA  7.232110e+09 -0.071233   10.17                  Energy
# 38  AUOTY  7.219426e+09 -0.053549    7.60              Technology
# 39   COTY  6.867017e+09 -0.060470    8.39      Consumer Defensive
# 40    PSO  6.794384e+09  0.061176    9.02       Consumer Cyclical
# 41    SID  6.493613e+09  0.012987    4.68         Basic Materials
# 42   COHR  6.300149e+09 -0.017293  255.16              Technology
# 43   LSTR  6.207126e+09 -0.026187  162.88             Industrials
# 44     GT  6.050603e+09 -0.108209   21.51       Consumer Cyclical
# 45    DCP  5.805291e+09 -0.039642   27.86                  Energy
# 46   IART  5.638448e+09 -0.032272   66.57              Healthcare
# 47   ORCC  5.610287e+09 -0.017218   14.27                 Unknown
# 48   ROLL  5.496894e+09 -0.069540  190.40             Industrials
# 49   PDCE  5.259554e+09 -0.043732   54.01                  Energy
# 50    LEG  5.205712e+09 -0.059065   39.03       Consumer Cyclical
# 51    IGT  5.191065e+09 -0.093705   25.34       Consumer Cyclical
# 52    TMX  5.146404e+09 -0.005851   42.48             Industrials
# 53    FCN  5.103153e+09 -0.016325  148.83             Industrials
# 54    CLH  5.068489e+09 -0.035015   93.15             Industrials

# %%
tickers = screen.ticker.tolist()
start_date = '2018-01-01'
end_date = '2022-01-01'

# %%
data_screen = screen[['ticker', 'Sector']]
data_screen.groupby('Sector').describe()
# Out:
#                        ticker
#                         count unique    top freq
# Sector
# Basic Materials             3      3    PKX    1
# Communication Services      3      3    SJR    1
# Consumer Cyclical          10     10    WPP    1
# Consumer Defensive          2      2    NWL    1
# Energy                      9      9    CVE    1
# Healthcare                  3      3   MASI    1
# Industrials                 9      9   GNRC    1
# Real Estate                 2      2   VICI    1
# Technology                  4      4    WDC    1
# Unknown                     3      3  EMRAF    1
# Unknown Sector              1      1   AMCR    1
# Utilities                   6      6    BIP    1

# %%
factor_index = pd.date_range(start=start_date, end=end_date, freq='B')
prices = pd.DataFrame(index=factor_index)
for ticker in tickers:
    try:
        ticker_data = yf.Ticker(ticker)
        price = ticker_data.history(start=start_date, end=end_date)
        price = price['Close']
        price.name = ticker
        prices = pd.merge(prices, price, how='left', left_index=True, right_index=True)
    except Exception:
        print(f'ticker - {ticker} not found')
# Out:
# - C-P-N: No data found, symbol may be delisted

# %%
prices = prices.fillna(method='ffill')

# %%
prices.index.freq = 'B'

# %%
factor = pd.DataFrame()
for ticker in tickers:
    try:
        short = quandl.get(f"FINRA/FNSQ_{ticker}", start_date=start_date, end_date=end_date)
        short = short['ShortVolume']/(short['TotalVolume'] - short['ShortExemptVolume'])
        short = short/short.shift(10)
        short.name = 'data'
        short_data = pd.DataFrame(index=factor_index)
        short_data.index.name = 'Date'
        short_data = pd.merge(short_data, pd.DataFrame(short), left_index=True, right_index=True, how='left')
        short_data['ticker'] = ticker
        short_data = short_data.reset_index().set_index(['Date', 'ticker'])
        factor = factor.append(short_data)
    except Exception:
        print(f'no data found for {ticker}')
# Out:
# no data found for EMRAF
# no data found for AUOTY

# %%
factor = factor.sort_index()
factor.index.levels[0].freq = 'B'

# %%
factor_groups = screen[['ticker', 'Sector']]
factor_groups = factor_groups.set_index('ticker')
factor_groups = factor_groups['Sector'].to_dict()

# %%
factor_data = get_clean_factor_and_forward_returns(
    factor,
    prices,
    groupby=factor_groups,
    quantiles=5,
    periods=(1, 5),
    filter_zscore=None
)
# Out:
# Dropped 11.5% entries from factor data: 11.5% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!

# %% [markdown]
# ## Clean Factor Data for Backtest

# %%
def compute_z_score(data: pd.Series):
    value = (data - data.mean())/data.std()
    value[abs(value) > 3] = np.sign(value) * value
    return value

grouper = factor_data.index.get_level_values('date')
factor_data['factor'] = factor_data['factor'].groupby(grouper).apply(compute_z_score)

# %%
factor_data
# Out:
#                         1D        5D    factor              group  \
# date       asset
# 2018-01-17 AQN    0.014679  0.012844  0.851256          Utilities
#            BEP   -0.004764 -0.000595 -1.758220          Utilities
#            BIP   -0.007636 -0.001851  1.077172          Utilities
#            CLF   -0.009423 -0.016490 -0.103060    Basic Materials
#            CLH   -0.030529 -0.002130  0.144829        Industrials
# ...                    ...       ...       ...                ...
# 2021-12-23 ULTA   0.000000  0.031654  0.280600  Consumer Cyclical
#            VICI   0.000000  0.035986 -0.046353        Real Estate
#            WDC    0.000000  0.068137  0.740364         Technology
#            WES    0.000000  0.024496 -0.342870             Energy
#            WPP    0.000000  0.015698 -0.158412  Consumer Cyclical
#
#                   factor_quantile
# date       asset
# 2018-01-17 AQN                  5
#            BEP                  1
#            BIP                  5
#            CLF                  3
#            CLH                  4
# ...                           ...
# 2021-12-23 ULTA                 4
#            VICI                 4
#            WDC                  5
#            WES                  3
#            WPP                  3
#
# [49012 rows x 5 columns]

# %% [markdown]
# ## Running Backtest

# %%
ic = factor_information_coefficient(factor_data=factor_data)
mean_ic = mean_information_coefficient(factor_data=factor_data)

# %%
pd.options.plotting.backend = "plotly"
fig = ic.boxplot()
fig.show()
# Out:
# <div>                            <div id="9e9d0007-30af-4775-9558-93dea2c98ca1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e9d0007-30af-4775-9558-93dea2c98ca1")) {                    Plotly.newPlot(                        "9e9d0007-30af-4775-9558-93dea2c98ca1",                        [{"alignmentgroup":"True","hovertemplate":"variable=%{x}<br>value=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1D","1 ...

# %%
mean_ic
# Out:
# 1D   -0.015039
# 5D   -0.004468
# dtype: float64

# %%
ic_fig = px.bar(mean_ic)
ic_fig.show()
# Out:
# <div>                            <div id="5878bbcf-bd66-4e23-bf1d-0ad5d0790697" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5878bbcf-bd66-4e23-bf1d-0ad5d0790697")) {                    Plotly.newPlot(                        "5878bbcf-bd66-4e23-bf1d-0ad5d0790697",                        [{"alignmentgroup":"True","hovertemplate":"variable=0<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"textposition":"auto","x":["1D","5D"],"xaxis":"x","y":[-0.015039066163505515,-0.004467549714055391],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"o ...

# %%
quantile_returns, std_err_ret = mean_return_by_quantile(factor_data=factor_data)

# %%
quantile_returns
# Out:
#                        1D        5D
# factor_quantile
# 1                0.000552 -0.000066
# 2                0.000314 -0.000006
# 3               -0.000087  0.001346
# 4               -0.000226 -0.000119
# 5               -0.000541 -0.001052

# %%
t_stats_quantile_returns = quantile_returns/std_err_ret
t_stats_quantile_returns
# Out:
#                        1D        5D
# factor_quantile
# 1                2.319657 -0.111613
# 2                1.270876 -0.010662
# 3               -0.304983  1.320990
# 4               -1.017785 -0.233381
# 5               -2.499651 -1.871542

# %%
quantile_plot_df = quantile_returns.reset_index().melt(id_vars=['factor_quantile'])
quantile_plot_df['factor_quantile'] = quantile_plot_df['factor_quantile'].astype(str)
quantile_plot_df = quantile_plot_df.set_index('factor_quantile')
fig = px.histogram(quantile_plot_df, x=quantile_plot_df.index, y="value",
                   color='variable', barmode='group',
                   height=400)
fig.show()
# Out:
# <div>                            <div id="7f570cbb-afce-465d-9002-a58bae3c789f" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f570cbb-afce-465d-9002-a58bae3c789f")) {                    Plotly.newPlot(                        "7f570cbb-afce-465d-9002-a58bae3c789f",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"variable=1D<br>factor_quantile=%{x}<br>sum of value=%{y}<extra></extra>","legendgroup":"1D","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1D","offsetgroup":"1D","orientation":"v","showlegend":true,"x":["1","2","3","4","5"],"xaxis":"x","y":[0.0005522793434923211,0.0003142892406627296,-8.736701217401904e-05,-0.00022555699255877426,-0.0005411117254594615],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"variable=5D<br>factor_quantile=%{x}<br>sum of value=%{y}<extra></extra>","legendgroup":"5D","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"5D","offsetgroup":"5D","orientation":"v","showlegend":true,"x":["1","2","3","4","5"],"xaxis":"x","y":[-6.573961152526355e-05,-5.7841979287723625e-06,0.0013462480313709974,-0.00011863299899558883,-0.0010521350912453358],"yaxis":"y","type":"histogram"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111 ...

# %%
factor_return_corr = factor_rank_autocorrelation(factor_data=factor_data)
factor_return_corr
# Out:
# date
# 2018-01-17         NaN
# 2018-01-18    0.579525
# 2018-01-19    0.260191
# 2018-01-22    0.285106
# 2018-01-23    0.065310
#                 ...
# 2021-12-17    0.324255
# 2021-12-20    0.132246
# 2021-12-21    0.418082
# 2021-12-22    0.344404
# 2021-12-23    0.428071
# Name: 1, Length: 991, dtype: float64

# %%
factor_return_corr.mean()
# Out:
# 0.28559525498212673

# %%
cumulative_returns = (1 + factor_returns(factor_data=factor_data)).cumprod()
cumulative_returns
# Out:
#                   1D        5D
# date
# 2018-01-17  0.999695  1.002436
# 2018-01-18  0.998198  1.004928
# 2018-01-19  1.003990  1.020767
# 2018-01-22  1.002362  1.038436
# 2018-01-23  1.006235  1.049310
# ...              ...       ...
# 2021-12-17  0.550231  0.553298
# 2021-12-20  0.549351  0.550508
# 2021-12-21  0.548864  0.551573
# 2021-12-22  0.549678  0.551583
# 2021-12-23  0.549678  0.550308
#
# [991 rows x 2 columns]

# %%
cumulative_returns.plot.line(title='Growth of Dollar - Factor Portfolio')
# Out:
# <div>                            <div id="881bc6b8-6452-44c6-86a9-dd592defd414" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("881bc6b8-6452-44c6-86a9-dd592defd414")) {                    Plotly.newPlot(                        "881bc6b8-6452-44c6-86a9-dd592defd414",                        [{"hovertemplate":"variable=1D<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"1D","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"1D","showlegend":true,"x":["2018-01-17T00:00:00","2018-01-18T00:00:00","2018-01-19T00:00:00","2018-01-22T00:00:00","2018-01-23T00:00:00","2018-01-24T00:00:00","2018-01-25T00:00:00","2018-01-26T00:00:00","2018-01-29T00:00:00","2018-01-30T00:00:00","2018-01-31T00:00:00","2018-02-01T00:00:00","2018-02-02T00:00:00","2018-02-05T00:00:00","2018-02-06T00:00:00","2018-02-07T00:00:00","2018-02-08T00:00:00","2018-02-09T00:00:00","2018-02-12T00:00:00","2018-02-13T00:00:00","2018-02-14T00:00:00","2018-02-15T00: